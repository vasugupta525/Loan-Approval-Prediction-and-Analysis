# %% [markdown]
# # <center>Loan Approval Prediction & Analysis</center>
#
# ![lap1.jpg](attachment:lap1.jpg)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Data PrePocessing

# %%
# finding the null values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# filling the missing values using mean and mode statistics
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

df['Gender'] = df["Gender"].fillna(df['Gender'].mode()[0])
df['Married'] = df["Married"].fillna(df['Married'].mode()[0])
df['Dependents'] = df["Dependents"].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df["Self_Employed"].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# categorical attributes visualization
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Gender', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Married', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Married Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(x = 'Dependents', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Dependents')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Education', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Graduation Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Self_Employed', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Self_Employed Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Property_Area', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Property Area')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Loan_Status', data=df, palette = 'Set1')
ax.set(title = 'Number of people who take loan according to Loan Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# creating histograms
plt.figure(figsize = (15,20))
plt.subplot(5,3,1)
sns.distplot(df['ApplicantIncome'])

plt.subplot(5,3,2)
sns.distplot(df['CoapplicantIncome'])

plt.subplot(5,3,3)
sns.distplot(df['LoanAmount'])

plt.subplot(5,3,4)
sns.distplot(df['Loan_Amount_Term'])

plt.subplot(5,3,5)
sns.distplot(df['Credit_History'])
# Out:
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %% [markdown]
# ## Creating New Column

# %%
# total income
df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
# creating histograms
plt.figure(figsize = (15,20))
plt.subplot(5,3,1)
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome']+1)
sns.distplot(df['ApplicantIncomeLog'])

plt.subplot(5,3,2)
df['CoapplicantIncomeLog'] = np.log(df['CoapplicantIncome']+1)
sns.distplot(df['CoapplicantIncomeLog'])

plt.subplot(5,3,3)
df['LoanAmountLog'] = np.log(df['LoanAmount']+1)
sns.distplot(df['LoanAmountLog'])

plt.subplot(5,3,4)
df['Loan_Amount_Term_Log'] = np.log(df['Loan_Amount_Term']+1)
sns.distplot(df['Loan_Amount_Term_Log'])

plt.subplot(5,3,5)
df['Total_Income_Log'] = np.log(df['Total_Income']+1)
sns.distplot(df['Total_Income_Log'])
# Out:
# <Axes: xlabel='Total_Income_Log', ylabel='Density'>

# %% [markdown]
# ## Finding Corelation using Heatmap

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True)
plt.show()

# %%
# drop unnecessary columns
cols = ['ApplicantIncome', 'CoapplicantIncome', "LoanAmount", "Loan_Amount_Term", "Total_Income", 'Loan_ID', 'CoapplicantIncomeLog']
df = df.drop(columns=cols, axis=1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.674197       4.993232
# 1         Rural           N            8.430327       4.859812
# 2         Urban           Y            8.006701       4.204693
# 3         Urban           Y            7.857094       4.795791
# 4         Urban           Y            8.699681       4.955827
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender',"Married","Education",'Self_Employed',"Property_Area","Loan_Status","Dependents"]
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])
    
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0              2            1            8.674197       4.993232
# 1              0            0            8.430327       4.859812
# 2              2            1            8.006701       4.204693
# 3              2            1            7.857094       4.795791
# 4              2            1            8.699681       4.955827
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %% [markdown]
# ## Train and Test Data Split

# %%
# specify input and output attributes
X = df.drop(columns=['Loan_Status'], axis=1)
y = df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Train Model

# %%
# classify function
from sklearn.model_selection import cross_val_score
def train(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    print("Accuracy is", model.score(x_test, y_test)*100)
    # cross validation - it is used for better validation of model
    # eg: cv-5, train-4, test-1
    score = cross_val_score(model, x, y, cv=5)
    print("Cross validation is",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
train(model, X, y)
# Out:
# Accuracy is 77.27272727272727
# Cross validation is 80.9462881514061

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
train(model, X, y)
# Out:
# Accuracy is 73.37662337662337
# Cross validation is 72.80421164867387

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model = RandomForestClassifier()
train(model, X, y)
# Out:
# Accuracy is 77.27272727272727
# Cross validation is 78.82980141276823

# %%
model = ExtraTreesClassifier()
train(model, X, y)
# Out:
# Accuracy is 75.32467532467533
# Cross validation is 77.36905237904838
